# %%
import pandas as pd

# %%
df=pd.read_csv('Employee_1000.csv')

# %%
df.head()
# Out:
#    Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0  850297         Ms.     Shawna              W       Buck      F
# 1  304721         Mr.  Nathaniel              Z      Burke      M
# 2  412317        Drs.  Elisabeth              W     Foster      F
# 3  621375        Mrs.     Briana              C  Lancaster      F
# 4  787549        Hon.    Estella              L     Potter      F
#
#                         E Mail      Father's Name     Mother's Name  \
# 0        shawna.buck@gmail.com       Rosario Buck       Keisha Buck
# 1  nathaniel.burke@walmart.com      Derrick Burke      Phoebe Burke
# 2   elisabeth.foster@gmail.com       Irwin Foster      Janie Foster
# 3   briana.lancaster@yahoo.com  Jeffrey Lancaster  Shelby Lancaster
# 4     estella.potter@gmail.com      Booker Potter    Katelyn Potter
#
#   Mother's Maiden Name       ...                 SSN    Phone No.   \
# 0            Hendricks       ...         222-11-7603  702-771-7149
# ...

# %%
df.describe()
# Out:
#               Emp ID  Age in Yrs.  Weight in Kgs.  Year of Joining  \
# count    1000.000000  1000.000000     1000.000000      1000.000000
# mean   549097.583000    40.377250       59.409000      2006.992000
# std    264810.879315    11.107729       13.900322         8.565588
# min    114425.000000    21.040000       40.000000      1980.000000
# 25%    307757.000000    30.925000       49.000000      2002.000000
# 50%    543073.000000    40.730000       57.000000      2009.000000
# 75%    788450.250000    49.852500       68.000000      2014.000000
# max    999475.000000    59.980000       90.000000      2017.000000
#
#        Month of Joining  Day of Joining  Age in Company (Years)  \
# count       1000.000000     1000.000000             1000.000000
# mean           6.415000       16.481000               10.093720
# std            3.428488        8.831514                8.568863
# min            1.000000        1.000000                0.000000
# ...

# %%
df.drop('Emp ID',axis=1,inplace=True)

# %%
df.drop('Password',axis=1,inplace=True)

# %%
df.drop("Father's Name",axis=1,inplace=True)

# %%
df.drop("Mother's Name",axis=1,inplace=True)

# %%
df.drop('User Name',axis=1,inplace=True)

# %%
df.head()
# Out:
#   Name Prefix First Name Middle Initial  Last Name Gender  \
# 0         Ms.     Shawna              W       Buck      F
# 1         Mr.  Nathaniel              Z      Burke      M
# 2        Drs.  Elisabeth              W     Foster      F
# 3        Mrs.     Briana              C  Lancaster      F
# 4        Hon.    Estella              L     Potter      F
#
#                         E Mail Mother's Maiden Name Date of Birth  \
# 0        shawna.buck@gmail.com            Hendricks    12/12/1971
# 1  nathaniel.burke@walmart.com                 Pugh    10/31/1993
# 2   elisabeth.foster@gmail.com              Delaney    11/26/1994
# 3   briana.lancaster@yahoo.com                Weiss    11/24/1975
# 4     estella.potter@gmail.com                 Pate     3/13/1995
#
#   Time of Birth  Age in Yrs.   ...     Salary Last % Hike          SSN  \
# 0   06:34:47 AM        45.66   ...     119090         17%  222-11-7603
# 1   02:02:38 AM        23.76   ...     117991         14%  550-99-9897
# ...

# %%
df.drop(['Name Prefix','E Mail','Phone No. ','Zip','Place Name','SSN'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   First Name Middle Initial  Last Name Gender Mother's Maiden Name  \
# 0     Shawna              W       Buck      F            Hendricks
# 1  Nathaniel              Z      Burke      M                 Pugh
# 2  Elisabeth              W     Foster      F              Delaney
# 3     Briana              C  Lancaster      F                Weiss
# 4    Estella              L     Potter      F                 Pate
#
#   Date of Birth Time of Birth  Age in Yrs.  Weight in Kgs. Date of Joining  \
# 0    12/12/1971   06:34:47 AM        45.66              44      12/18/2010
# 1    10/31/1993   02:02:38 AM        23.76              52       4/25/2017
# 2    11/26/1994   03:48:27 PM        22.68              42       3/27/2017
# 3    11/24/1975   09:44:16 PM        41.70              43       2/25/2003
# 4     3/13/1995   09:30:28 PM        22.39              58      10/11/2016
#
#     ...    Day of Joining DOW of Joining  Short DOW  Age in Company (Years)  \
# ...

# %%
df.drop(["Mother's Maiden Name",'Date of Birth','Time of Birth','Weight in Kgs.','Date of Joining','DOW of Joining'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   First Name Middle Initial  Last Name Gender  Age in Yrs. Quarter of Joining  \
# 0     Shawna              W       Buck      F        45.66                 Q4
# 1  Nathaniel              Z      Burke      M        23.76                 Q2
# 2  Elisabeth              W     Foster      F        22.68                 Q1
# 3     Briana              C  Lancaster      F        41.70                 Q1
# 4    Estella              L     Potter      F        22.39                 Q4
#
#   Half of Joining  Year of Joining  Month of Joining Month Name of Joining  \
# 0              H2             2010                12              December
# 1              H1             2017                 4                 April
# 2              H1             2017                 3                 March
# 3              H1             2003                 2              February
# 4              H2             2016                10               October
#
# ...

# %%
df.drop(["City",'Year of Joining','Month of Joining','Month Name of Joining','Short DOW','Day of Joining'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   First Name Middle Initial  Last Name Gender  Age in Yrs. Quarter of Joining  \
# 0     Shawna              W       Buck      F        45.66                 Q4
# 1  Nathaniel              Z      Burke      M        23.76                 Q2
# 2  Elisabeth              W     Foster      F        22.68                 Q1
# 3     Briana              C  Lancaster      F        41.70                 Q1
# 4    Estella              L     Potter      F        22.39                 Q4
#
#   Half of Joining Short Month  Age in Company (Years)  Salary Last % Hike  \
# 0              H2         Dec                    6.61  119090         17%
# 1              H1         Apr                    0.26  117991         14%
# 2              H1         Mar                    0.34  161045         28%
# 3              H1         Feb                   14.43  142616         16%
# 4              H2         Oct                    0.79  135706         11%
#
#                  County State   Region
# ...

# %%
df.drop(["Middle Initial",'Short Month','First Name','Last Name'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Gender  Age in Yrs. Quarter of Joining Half of Joining  \
# 0      F        45.66                 Q4              H2
# 1      M        23.76                 Q2              H1
# 2      F        22.68                 Q1              H1
# 3      F        41.70                 Q1              H1
# 4      F        22.39                 Q4              H2
#
#    Age in Company (Years)  Salary Last % Hike                County State  \
# 0                    6.61  119090         17%                 Clark    NV
# 1                    0.26  117991         14%                  Lake    MI
# 2                    0.34  161045         28%               Fayette    KY
# 3                   14.43  142616         16%                  Lake    IN
# 4                    0.79  135706         11%  Fairbanks North Star    AK
#
#     Region
# 0     West
# 1  Midwest
# 2    South
# 3  Midwest
# 4     West

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.stripplot(x='Gender',y='Salary',data=df)
plt.title('Stripplot')
plt.show()

# %%
df.Salary.hist(bins=10)

# %%
plt.scatter(df["Age in Company (Years)"],df['Salary'])

# %%
df.plot.bar('Region','Salary')

# %%
df.plot.bar('Gender','Salary',rot=0)

# %%
df.corr()
# Out:
#                         Age in Yrs.  Age in Company (Years)    Salary
# Age in Yrs.                1.000000                0.676408  0.041422
# Age in Company (Years)     0.676408                1.000000  0.054212
# Salary                     0.041422                0.054212  1.000000

# %%
sns.heatmap(df.corr())

# %%
df.isnull().sum()
# Out:
# Gender                    0
# Age in Yrs.               0
# Quarter of Joining        0
# Half of Joining           0
# Age in Company (Years)    0
# Salary                    0
# Last % Hike               0
# County                    0
# State                     0
# Region                    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['Gender']=le.fit_transform(df['Gender'])

# %%
df['Quarter of Joining']=le.fit_transform(df['Quarter of Joining'])

# %%
df['Half of Joining']=le.fit_transform(df['Half of Joining'])

# %%
df['County']=le.fit_transform(df['County'])

# %%
df['State']=le.fit_transform(df['State'])

# %%
df['Last % Hike']=le.fit_transform(df['Last % Hike'])

# %%
df['Region']=le.fit_transform(df['Region'])

# %%
df.head()
# Out:
#    Gender  Age in Yrs.  Quarter of Joining  Half of Joining  \
# 0       0        45.66                   3                1
# 1       1        23.76                   1                0
# 2       0        22.68                   0                0
# 3       0        41.70                   0                0
# 4       0        22.39                   3                1
#
#    Age in Company (Years)  Salary  Last % Hike  County  State  Region
# 0                    6.61  119090            9     106     32       3
# 1                    0.26  117991            6     276     21       0
# 2                    0.34  161045           21     184     16       2
# 3                   14.43  142616            8     276     14       0
# 4                    0.79  135706            3     177      0       3

# %%
x=df.drop('Salary',axis=1)

# %%
y=df['Salary']

# %%
x.shape
# Out:
# (1000, 9)

# %%
y.shape
# Out:
# (1000,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=45)

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lm.score(x_train,y_train)
# Out:
# 0.015858647165011286

# %%
lm.predict(x_test)
# Out:
# array([131983.71112946, 121197.74949075, 113306.50204539, 120607.55231058,
#        124185.452069  , 116700.22304393, 119644.79443553, 124099.09061893,
#        118604.03643735, 122457.94861562, 115631.618746  , 116356.91709543,
#        110389.8335274 , 125277.60915318, 118131.62899706, 106493.87639587,
#        111980.63564747, 124330.65489092, 124182.84773865, 118944.03962682,
#        116245.77610485, 122056.98843284, 117644.46557721, 125869.70829703,
#        121464.50729197, 124725.0950018 , 118659.13186307, 123355.45770558,
#        114940.08773296, 126965.36332562, 118841.2033899 , 119949.3893661 ,
#        111531.04560023, 129648.84636494, 112929.96352275, 122535.28120742,
#        118870.18463829, 110700.51632679, 132621.28817292, 112331.35777271,
#        114739.00611152, 118797.16060488, 116980.41454551, 114914.53687525,
#        132533.10915366, 115006.64189381, 125032.21549995, 126768.58398918,
# ...

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
sns.pairplot(df)

# %%
mean_squared_error(y_test,lm.predict(x_test))
# Out:
# 2053389181.5650048

# %%
mean_absolute_error(y_test,lm.predict(x_test))
# Out:
# 38672.00678709167

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn= KNeighborsRegressor()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#           weights='uniform')

# %%
knn.score(x_train,y_train)
# Out:
# 0.20265028134386306

# %%
lm.predict(x_test)
# Out:
# array([131983.71112946, 121197.74949075, 113306.50204539, 120607.55231058,
#        124185.452069  , 116700.22304393, 119644.79443553, 124099.09061893,
#        118604.03643735, 122457.94861562, 115631.618746  , 116356.91709543,
#        110389.8335274 , 125277.60915318, 118131.62899706, 106493.87639587,
#        111980.63564747, 124330.65489092, 124182.84773865, 118944.03962682,
#        116245.77610485, 122056.98843284, 117644.46557721, 125869.70829703,
#        121464.50729197, 124725.0950018 , 118659.13186307, 123355.45770558,
#        114940.08773296, 126965.36332562, 118841.2033899 , 119949.3893661 ,
#        111531.04560023, 129648.84636494, 112929.96352275, 122535.28120742,
#        118870.18463829, 110700.51632679, 132621.28817292, 112331.35777271,
#        114739.00611152, 118797.16060488, 116980.41454551, 114914.53687525,
#        132533.10915366, 115006.64189381, 125032.21549995, 126768.58398918,
# ...

# %%
mean_squared_error(y_test,knn.predict(x_test))
# Out:
# 2524206919.5670667

# %%
mean_absolute_error(y_test,knn.predict(x_test))
# Out:
# 41835.44066666666

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf= RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
rf.score(x_train,y_train)
# Out:
# 0.7913164754843159

# %%
rf.predict(x_test)
# Out:
# array([133328.8, 124487.7, 103317.7, 122186.6, 130259.5,  87232.2,
#        129440.2, 110638.3, 120254. ,  90256.6, 122772.8, 102939.1,
#        127510.5, 120958.1, 120118.1,  98323.5, 125115.5, 142431.2,
#        112055.3, 118681.2, 127984. , 134756.5, 122745.1, 124945. ,
#         89879.7, 137530.1, 118353.1, 123383.2, 148922.8, 121398.2,
#        141552.5, 130349.7, 104274.3, 133152.5, 107750.2, 127202.4,
#        151118.5, 152371.2,  92447.3,  94116.4, 129489.8, 144793.5,
#        105772.8,  87157. , 103774. , 113847.9, 144256.1, 122738. ,
#        110833.2, 167575.4,  89904.2,  81445.7, 160880.8, 120772. ,
#        132027.1, 113208.2, 148625.3, 112467. , 107119.1, 135549.9,
#        119790.6, 150927.8, 134622.5,  97702.5, 109108.2, 132570.9,
#        114990.3, 110134.5, 148056.2, 145450.8, 107242.6, 130037.2,
#        113418.8, 143905.9, 124061.8, 117780.2, 133169.2, 120594.5,
#         98797.7, 128283. , 106027.5,  98175.2,  98932.1, 101264.6,
# ...

# %%
mean_squared_error(y_test,rf.predict(x_test))
# Out:
# 2450450603.9405

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,rf.predict(x_test))
# Out:
# -0.2143911115347119

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z
# Out:
# array([[1.01816496, 0.47583025, 1.35808004, ..., 1.17586374, 0.52610404,
#         1.49185658],
#        [0.98215912, 1.49675646, 0.43951101, ..., 0.12296052, 0.24737156,
#         1.32296716],
#        [1.01816496, 1.59403471, 1.33830654, ..., 0.69276697, 0.59895138,
#         0.553582  ],
#        ...,
#        [1.01816496, 1.75666052, 1.33830654, ..., 1.29536206, 1.44274295,
#         1.49185658],
#        [1.01816496, 0.91578914, 1.33830654, ..., 0.72373471, 1.30211102,
#         0.38469258],
#        [1.01816496, 1.74765327, 1.33830654, ..., 0.09381368, 0.73705194,
#         0.553582  ]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([594, 621, 684, 999], dtype=int64), array([4, 4, 4, 4], dtype=int64))

# %% [markdown]
# # There are not much outlier and therefore we can say that Linear Regression algorithm is working better than other but still it is not a good model
